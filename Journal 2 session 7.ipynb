# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,1,100)
def main():
    return np.exp(x)

# %%
y = np.exp(x)
plt.plot(x,y)
plt.xlabel("Time[miliseconds]")
plt.ylabel("Awesomeness")
plt.savefig('Journal7.pdf' ,bbox_inches="tight" ,dpi=600)
